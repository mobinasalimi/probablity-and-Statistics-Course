# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br />
# 			<br />
# پاییز ۱۴۰۱
# 		</div>
# 		<hr/>
# 		<div align=center>
# 		    <font color=red size=6>
# 			    <br />
# تمرین عملی سری سوم
#             	<br/>
# 			</font>
#             نام و نام خانوادگی:مبینا سلیمی پناه
#             <br/>
#             شماره دانشجویی: ۹۹۱۰۹۷۸۸
#             <br/><br/>
#             طراحان: آیناز رفیعی، علیرضا حبیب‌زاده
# 			<br/>
# موعد تحویل: ۱۴ آذر
#                 <br/>
#                 همفکری در تمامی تمرین‌های درس توصیه می‌شود. در عین حال از شما انتظار می‌رود تمام پیاده‌سازی را به تنهایی و بدون مشاهده کد دیگران انجام دهید.
#                 <br/><br/>
#                 <font color=red>
#                 لطفا در فایل ارسالی تمام بلوک‌های کد اجرا شده و شامل نمودار‌ها و خروجی‌های لازم باشند.
#      </font>
#                 <br/>
#         </style>
# 	</font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#           سوال اول
#         </font>
#         <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#                 <hr/>
#        تابعی از یک نمونه از یک متغیر تصادفی uniform بین 0 و 1 به نمونه ای از متغیر تصادفی نمایی بیابید.
#    </font>
# </div>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# پاسخ:
#
# </div>

# %%
uniform_to_exp <- function(z){
    return(-1/4 * log(z))
}

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#                 <hr/>
#        50000 نمونه از متغیر تصادفی uniform بین 0 و 1 تولید کرده و تابع بالا را روی آن اعمال کنید. پارامتر توزیع نمایی را دلخواه در نظر بگیرید ولی آن را ذکر کنید. نتیجه را بر روی نمودار نمایش دهید.
#    </font>
# </div>
#     </font>
# </div>

# %%
result <- uniform_to_exp(runif(50000, min= 0, max= 1))
hist(result, freq=FALSE, col = "coral")
# Out:
# Plot with title “Histogram of result”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <hr/>
# 10000 نمونه از متغیر تصادفی binomial با استفاده از متغیرهای تصادفی از توزیع نمایی که در مرحله‌ی قبل به دست آورده‌اید تولید کرده و بر روی نمودار نمایش دهید.<br/>
#         پارامترهای توزیع را دلخواه انتخاب کنید ولی آن‌ها را ذکر کنید.
#     </font>
# </div>

# %%
binom <- rbinom(result, size=10000, prob=0.4)
hist(binom, freq = FALSE, col = "palegreen")
#parameter = 0.4
# Out:
# Plot with title “Histogram of binom”

# %% [markdown]
# <br>
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             سوال دوم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
#             در اتاقی یک بلندگو (فرستنده) قرار دارد که سیگنالی ارسال می‌کند
#         و همچنین سه میکروفون (گیرنده) در فواصل و جاهای مختلف قرار داده شده‌اند که این سیگنال را دریافت می‌کنند.
#             اطلاعات سیگنال ارسال شده و دریافتی بر حسب زمان در دیتاست
# data.csv
# به شما داده شده است. <br>
# داده‌ها را در یک دیتافریم لود کنید.
# </div>
#     </font>
# </div>

# %%
data <- read.csv("data.csv")
head(data)
# Out:
#   X time send     receive1 receive2 receive3
# 1 1  0   50.00000 47.82258 47.71930 50.03958
# 2 2  5   50.31411 47.38460 47.82535 49.92389
# 3 3 10   50.62791 47.53287 47.95819 49.78453
# 4 4 15   50.94108 47.74043 47.77721 49.87762
# 5 5 20   51.25333 47.82595 47.88115 49.80018
# 6 6 25   51.56434 47.89652 48.00486 49.77694

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# نمودار اطلاعات فرستنده و سه گیرنده بر حسب زمان را در یک نمودار بکشید.
#     </font>
# <div>

# %%
library(ggplot2)

ggplot(data) + 
  geom_point(mapping = aes(x = time, y = receive1 , shape = "reciever1")) +
  geom_point(mapping = aes(x = time, y = receive2 , shape = "reciever2")) +
  geom_point(mapping = aes(x = time, y = receive3 , shape = "reciever3")) +
  geom_point(mapping = aes(x = time, y = send , shape = "sender")) + labs(y = "data")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#                 <hr/>
# داده‌های اندازه‌گیری شده به دلیل تفاوت و فاصله‌ی گیرنده‌ها و عوامل محیطی ممکن است دچار تغییراتی شده باشند.
# به همین منظور لازم است تا داده‌ها را نرمالایز کنیم.
# یعنی تبدیل خطی‌ای روی آن‌ها اعمال کنیم که توزیع نهایی دارای امید ریاضی صفر و انحراف معیار واحد باشد.
# $$x' = \frac{x - \bar{x}}{\sigma_x}$$
# داده‌های نرمالایز شده‌ی فرستنده و سه گیرنده را به دیتافریم اضافه کنید.
# از این به بعد تنها با داده‌های نرمالایز شده کار خواهیم کرد.
#     </font>
# </div>

# %%
data$send_normalized <- (data$send - mean(data$send)) / sd(data$send)
data$r1_normalized <- (data$receive1 - mean(data$receive1)) / sd(data$receive1)
data$r2_normalized <- (data$receive2 - mean(data$receive2)) / sd(data$receive2)
data$r3_normalized <- (data$receive3 - mean(data$receive3)) / sd(data$receive3)

head(data)
# Out:
#   X time send     receive1 receive2 receive3 send_normalized r1_normalized
# 1 1  0   50.00000 47.82258 47.71930 50.03958 0.00000000      -0.5661115
# 2 2  5   50.31411 47.38460 47.82535 49.92389 0.04442152      -0.6806540
# 3 3 10   50.62791 47.53287 47.95819 49.78453 0.08879920      -0.6418786
# 4 4 15   50.94108 47.74043 47.77721 49.87762 0.13308925      -0.5875953
# 5 5 20   51.25333 47.82595 47.88115 49.80018 0.17724796      -0.5652290
# 6 6 25   51.56434 47.89652 48.00486 49.77694 0.22123174      -0.5467747
#   r2_normalized r3_normalized
# 1 -1.523544      0.04769859
# 2 -1.452570     -0.07810391
# 3 -1.363669     -0.22963938
# 4 -1.484789     -0.12841165
# 5 -1.415226     -0.21262445
# 6 -1.332436     -0.23789314

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# برای اطمینان میانگین و واریانس داده‌های نرمالایز شده را حساب کنید.
# <br>
# آیا نتیجه با آنچه انتظار دارید یکسان است؟
#     </font>
# </div>

# %%
print(mean(c(data$send_normalized)))
print(var(data$send_normalized))

print(mean(c(data$r1_normalized)))
print(var(data$r1_normalized))

print(mean(c(data$r2_normalized)))
print(var(data$r2_normalized))

print(mean(c(data$r3_normalized)))
print(var(data$r3_normalized))
# Out:
# [1] 4.839046e-17
# [1] 1
# [1] -8.887321e-16
# [1] 1
# [1] 6.057776e-16
# [1] 1
# [1] 2.714873e-15
# [1] 1

# %% [raw]
#  با توجه به نتایج بدست آنده مشاهده می‌شود که واریانش دقیقا برار یک و میانگین داده‌ها خیلی نزدیک به صفر می‌باشد که با انتظار ما مطابقت دارد.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# داده‌های نرمالایز شده‌ی گیرنده‌ها و فرستنده بر حسب زمان را در یک نمودار نشان دهید.
# </font>
# </div>

# %%
library(ggplot2)

ggplot(data) +
  geom_point(mapping = aes(x = time, y = r1_normalized , col = 'r1_normalized')) +
  geom_point(mapping = aes(x = time, y = r2_normalized , col = 'r2_normalized')) + 
  geom_point(mapping = aes(x = time, y = r3_normalized , col = 'r3_normalized')) +
  geom_point(mapping = aes(x = time, y = send_normalized , col = 'sender_normalized')) +
  labs(y = "normalized_data")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# توزیع توام داده‌های نرمالایز شده‌ی سه گیرنده با فرستنده را در نمودار یا نمودارهای مناسبی نمایش دهید.
# <br>
# <font size=3>
# (راهنمایی: جواب‌ها همگی نوعی بیضی هستند)
# </font>
# <br>
# توزیع حاشیه‌ای هر کدام از متغیرهای نرمالایز شده‌ی
# send,
# receive1,
# receive2,
# receive3
# را به صورت جداگانه یا روی همان توزیع توام نمایش دهید.
# <br>
# برای این کار می‌توانید از
# ggMarginal
# از کتابخانه‌ی
# ggExtra
# استفاده کنید. (یا نکنید)
#     </font>
# </div>

# %%
library(ggExtra)
library(gridExtra)

df1 <- data.frame(x=data$send_normalized,y= data$r1_normalized)
r1 <- ggplot(df1, aes(x, y)) + geom_point(col = "green")
r1 <- ggMarginal(r1, type = "h")
df2 <- data.frame(x=data$send_normalized,y= data$r2_normalized)
r2 <- ggplot(df2, aes(x,y)) + geom_point(col = "green")
r2 <- ggMarginal(r2, type = "h")
df3 <- data.frame(x=data$send_normalized,y= data$r3_normalized)
r3 <- ggplot(df3, aes(x, y)) + geom_point(col = "green")
r3 <- ggMarginal(r3, type = "h")
grid.arrange(r1 , r2 , r3 )
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         کوواریانس اطلاعات نرمالایز شده‌ی گیرنده‌ها با فرستنده را حساب کنید. (سه مقدار)
# <br>
#         مقادیر به دست‌آمده را با توزیع‌های توام که در قسمت قبل کشیدید مقایسه کنید.
#         <br>
#         (به کوواریانس بین توزیع‌های نرمالایز شده کوریلیشن نیز می‌گویند که مقداری بین منفی یک و یک است.)
# </font>
# </div>

# %%
print(cov(data$r1_normalized, data$send_normalized)) 
print(cov(data$r2_normalized, data$send_normalized))
print(cov(data$r3_normalized, data$send_normalized))
#r1_normalized: با توجه به نمودار قسمت قبل که یک بیضی صعودی است انتظار میرفت حاصل کوواریانس، یک عدد مثبت باشد و میبینیم که هست.
#r2_normalized: با توجه به نمودار قسمت قبل که دایره است انتظار میرفت حاصل کوواریانس، یک عدد نزدیک به صفر باشد و میبینیم که هست.
#r3_normalized: با توجه به نمودار قسمت قبل انتظار میرفت حاصل کوواریانس، یک عدد منفی باشد و میبینیم که هست.
# Out:
# [1] 0.8628303
# [1] -0.00724553
# [1] -0.9967574

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         <font size=6>
#     امتیازی
# </font>
# <br>
# همان‌طور که احتمالا حدس زدید گیرنده‌ها علاوه بر آن که اطلاعات را با مقداری نویز و تضعیف شده دریافت می‌کنند آن را با تاخیر هم می‌بینند.
# یعنی نمودار داده‌های گیرنده‌ها در مقایسه با داده‌های فرستنده شیفت خورده است.
# به دلیل نویزی که در اطلاعات وجود دارد هیچوقت نقاط با شیفت دادن دقیقا روی هم قرار نمی‌گیرند.
# یک روش خوب برای پیدا کردن تاخیر بین این دو موج شیفت دادن یک موج و محاسبه‌ی کوواریانس بین این دو است تا جایی که این کوواریانس بیشینه شود.
# <br>
# (اگر نویزی وجود نداشت این مقدار برای داده‌های نرمالایز شده‌ی یک می‌بود چرا که کوواریانس یک متغیر نرمالایز شده با خودش یک است )
# <br><br>
# داده‌های گیرنده‌ی اول را به ازای جابه‌جایی‌های مضرب 5 از صفر تا 1000 میکروثانیه (نصف کل بازه‌ی زمانی) به سمت چپ شیفت دهید. سپس داده‌های 1000 میکروثانیه ابتدایی از فرستنده و گیرنده باقی می‌ماند را جدا کنید و کوواریانس این دو را محاسبه کنید.
# حال نمودار کوواریانس بر حسب شیفت را رسم کنید.
# <br><br>
# (راهنمایی:
# همیشه باید 200
# داده از میان ستون receive1 نرمالایز شده بردارید
# و کوواریانس آن را با 200 داده‌ی ابتدایی
# send نرمالایز شده حساب کنید.)
# </font>
# </div>
#
# <img src="pic1.png" width=500/>

# %%
covariance <- 0
shift <- 0
for(i in 1:200){
     shift[i] = i * 5
    send <- data[data$X <= 200, ]
    recieve <- data[i < data$X & data$X <= 200+i, ]
    covariance[i] =cov(send$send_normalized, recieve$r1_normalized)
}
shift <- shift[shift <=1000]
ggplot() +  geom_point(mapping = aes(x = shift, y = covariance), col = "khaki")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# شیفتی که در آن بیشترین کوواریانس بین داد‌های گیرنده‌ی شیفت خورده و فرستنده ایجاد می‌شود و کوواریانس بیشینه را پیدا کنید.
#     </font>
# </div>

# %%
print(which(covariance == max(covariance)) * 5)
print(max(covariance))
# Out:
# [1] 80
# [1] 1.002021

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# توزیع توام 1000 میکروثانیه اول گیرنده‌ی شیفت خورده با فرستنده را رسم کنید.
# </font>
# </div>

# %%
data[1:200, ]$r1_normalized <- data$r1_normalized[17: 216]
ggplot(data[1:200, ]) + geom_point(aes(x=send_normalized, y=r1_normalized), col = "lightblue")
# Out:
# plot without title
