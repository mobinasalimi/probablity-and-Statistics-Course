# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br />
# 			<br />
# پاییز 1401
# 		</div>
# 		<hr/>
# 		<div align=center>
# 		    <font color=red size=6>
# 			    <br />
# تمرین عملی بخش دوم
#             	<br/>
# 			</font>
# طراحان: محمدجواد ماهرالنقش، محمد‌مهدی ابوترابی
# 			<br/><br/>
# موعد تحویل: 14 آبان
#                 <br/>
#                 همفکری در تمامی تمرین‌های درس توصیه می‌شود. در عین حال از شما خواسته می‌شود تا تمام پیاده‌سازی را به تنهایی و بدون مشاهده کد دیگران انجام دهید.
#                 <br/><br/>
#                 <font color=red>
#                 لطفا در فایل ارسالی تمام بلوک‌های کد اجرا شده و شامل نمودار‌ها و خروجی‌های لازم باشند.
#      </font>
#                 <br/>
#         </style>
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl">
#  نام و نام خانوادگی: مبینا سلیمی پناه
# </div>

# %% [markdown]
# <div style="direction:rtl">
#     شماره دانشجویی: ۹۹۱۰۹۷۸۸
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال اول
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     دیتافریم airquality یکی از دیتا فریم‌های biult-in است که اطلاعاتی در مورد وضعیت آب‌و‌هوای نیویورک در یک بازه‌ی زمانی می‌دهد.
#             </font>
# </div>
#     </font>
# </div>

# %%
head(airquality)
# Out:
#   Ozone Solar.R Wind Temp Month Day
# 1 41    190      7.4 67   5     1
# 2 36    118      8.0 72   5     2
# 3 12    149     12.6 74   5     3
# 4 18    313     11.5 62   5     4
# 5 NA     NA     14.3 56   5     5
# 6 28     NA     14.9 66   5     6

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         الف)
# به کمک boxplot‌ها یک نمودار مناسب ارائه دهید که وضعیت دما (temp) را بر حسب ماه‌های مختلف نشان دهد.
#      </font>
# </div>

# %%
boxplot(Temp ~ Month, data = airquality, xlab = "month",
   ylab = "temp")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ب) بخش الف را برای میانگین باد و میانگین غلظت اوزون و میانگین تابش خورشید بر حسب ماه‌های مختلف تکرار کنید و نتایج خود را از این 4 نمودار شرح دهید.
#      </font>
# </div>

# %%
boxplot(Wind ~ Month, data = airquality, xlab = "month",
   ylab = "wind")
boxplot(Solar.R ~ Month, data = airquality, xlab = "month",
   ylab = "Solar.R")
boxplot(Ozone ~ Month, data = airquality, xlab = "month",
   ylab = "Ozone")

# result :میزان وزش باد حدودا در رنج۷ تا ۱۴ قرار دارد و این رنج در ماه‌های مختلف سال تقریبا ثابت است ولی به گونه ای که از ماه ۵ تا ۷ در حال افزایش پس
#از آن در حال کاهش می باشد.
#تابش نور خورشید نیز تقریبا در بازه ۷۰ تا ۲۹۰ قرار گرفته است که این رنج در ماه ۵ از همه بیشتر و در ماه ۷ کمتر و نسبتا ثابت تر بوده است. در سه ماه دیگر نیز
# این رنج تقریبا یکسان و در بازه ۹۰ تا ۲۷۰ است.
# میزان غلظت اوزون نیز در بازه ای بین ۱۰ تا ۷۰ تقریبا قرار گرفته و این رنج در ماه های ۷ و ۸ گسترده تر است. همچنین خور غلظت اوزون نیز در این دو ماه بیشتر
#می باشد
#دمای هوا نیز در بازه ۶۰ تا ۸۷ تقریبا قرار گرفته است و در ماه ۷ نیز کمتر تغییر میکند و تقریبا ثابت است.در ماه های ۷ و ۸ می تواند به بیشترین مقدار خود برسد و
#در ماه ۵ در کمترین مقدار.
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ج) به کمک boxplot‌ها رنج اعداد مختلف در پارامتر‌های متفاوت را در این دیتاست را بررسی کنید.
#      </font>
# </div>

# %%
boxplot(airquality)
# بررسی : همان توضیحات قسمت ب
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# د) به کمک نمودار scatter نمودار میانگین غلظت اوزون بر حسب دما را رسم کنید و آن را تحلیل کنید.
#      </font>
# </div>

# %%
plot(x = airquality$Temp,y = airquality$Ozone,xlab = "temp",ylab = "ozone")
#میانگین غلظت اوزون از دمای ۸۰ به بعد با افزایش دما افزایش میابد و تا قبل از آن ثابت است.
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ه) نمودار نقطه‌ای (scatter) را براساس ویژگی‌های جذر میانگین غلظت اوزون و ماه و باد رسم کنید. سعی کنید نمودار رسم شده اطلاعات را به خوبی نشان دهد. نتایج خود را بیان کنید. (به وابستگی میان متغیر‌ها توجه کنید.)
#      </font>
# </div>

# %%
plot(Ozone ^ (0.5) ~ Wind, data = airquality, col=factor(Month))
#
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# و) نمودار هیستوگرام برای باد و  تابش خورشید رسم کنید، این دو نمودار را با هم و با نمودار توزیع نرمال مقایسه کنید و نتیجه‌ی خود را آن بیان کنید.
#      </font>
# </div>

# %%
hist(airquality$Wind, xlab = "wind")
hist(airquality$Solar.R, xlab = "solar.r")
# نمودار مربوط به باد به توزیع نرمال نزدیک تر است ولی نمودار تابش خورشید تقریبا می توان گفت ربطی به توذیع نرمال ندارد
# Out:
# Plot with title “Histogram of airquality$Wind”
# Plot with title “Histogram of airquality$Solar.R”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال دوم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#         در یک فرایند پواسون زمان بین دو اتفاق از یک توزیع نمایی پیروی می‌کند. اگر بخواهیم زمان اتفاق n‌ام را پیش‌بینی کنیم از توزیع گاما استفاده می‌کنیم.
#         $$T_n=\sum_{i=1}^n{X_i},\  X_i  s\ are\ i.i.d\ and\ X_i\sim Exp(\lambda)$$
#         $$T_n\sim Gamma(n, \lambda)$$
# حال فرض کنید فاصله بین ورود مشتریان به یک رستوران از توزیع نمایی پیروی می‌کند به طوری که در هر دقیقه پنج مشتری وارد می‌شوند.
#         <br>
#         الف)
#  2000  نمونه تصادفی برای زمان بین ورود مشتریان تولید کنید و نمودارهای هیستوگرام داده‌های تولیدشده و چگالی توزیع آن را در یک نمودار رسم کنید. نمودار هیستوگرام شما باید چگالی احتمال را برای هر نمونه را نشان دهد.
#             </font>
# </div>
#     </font>
# </div>

# %%
data <- rexp(2000, 5)
hist(data, freq = FALSE)
# Out:
# Plot with title “Histogram of data”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ب)
#         بی‌حافظگی توزیع نمایی را با داده‌های تولید شده در قسمت قبل را با استفاده از داده‌های تولید شده در قسمت قبل و رسم نمودار به همان شکل نشان دهید.
#      </font>
# </div>

# %%
data_2 <- data[1000:2000]
hist(data_2, freq = FALSE)
# Out:
# Plot with title “Histogram of data_2”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ج)
#        با تولید n=10 متغیرتصادفی نمایی، ویژگی گفته شده در صورت سوال را بررسی کنید. برای این‌کار می‌توانید برای شبیه‌سازی هر متغیرتصادفی مانند قسمت الف عمل کنید.
#      </font>
# </div>

# %%
Gamma <- rexp(2000, rate=5)
for (i in 1:10){
    Gamma <- Gamma + rexp(2000, rate=5)
}

hist(Gamma, prob = TRUE)
lines(density(Gamma),
      lwd = 2,
      col = "blue")
# Out:
# Plot with title “Histogram of Gamma”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال سوم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     دیتاست مربوط به درآمد در پیوست موجود است. <br>
#     الف) به وسیلۀ دستور read.csv اطلاعات دیتاست را بخوانید. (دیتاست adult.csv)
#             </font>
# </div>
#     </font>
# </div>

# %%
df <- read.csv("./adult.csv")
head(df)
# Out:
#   age workclass fnlwgt education    educational.num marital.status
# 1 25  Private   226802 11th          7              Never-married
# 2 38  Private    89814 HS-grad       9              Married-civ-spouse
# 3 28  Local-gov 336951 Assoc-acdm   12              Married-civ-spouse
# 4 44  Private   160323 Some-college 10              Married-civ-spouse
# 5 18  ?         103497 Some-college 10              Never-married
# 6 34  Private   198693 10th          6              Never-married
#   occupation        relationship  race  gender capital.gain capital.loss
# 1 Machine-op-inspct Own-child     Black Male      0         0
# 2 Farming-fishing   Husband       White Male      0         0
# 3 Protective-serv   Husband       White Male      0         0
# 4 Machine-op-inspct Husband       Black Male   7688         0
# 5 ?                 Own-child     White Female    0         0
# 6 Other-service     Not-in-family White Male      0         0
#   hours.per.week native.country income
# 1 40             United-States  <=50K
# 2 50             United-States  <=50K
# 3 40             United-States  >50K
# 4 40             United-States  >50K
# 5 30             United-States  <=50K
# 6 30             United-States  <=50K

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         نمودار مربوط به درآمد را برحسب سن/جنسیت به کمک نمودارهای زیر بکشید.
#      </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#          ب) نمودار Bar Plot (درآمد برحسب جنسیت و سن)
#      </font>
# </div>

# %%
library(ggplot2)

ggplot(df, aes(x = income, y=age, fill=gender)) +
  geom_bar(stat="identity", position=position_dodge())
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ج) نمودار Scatter Plot
#      </font>
# </div>

# %%
ggplot(df, aes(x = age, y=income, col=gender)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         د) نمودار Histogram (مربوط به سن که اطلاعات زن و مرد در یک نمودار به طور تلفیقی باشد)
#      </font>
# </div>

# %%
ggplot(df, aes(x = age, fill=income)) + geom_histogram(color="white", bins = 20)
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#        ه) نمودار Density Plot (مربوط به سن که اطلاعات زن و مرد در یک نمودار به طور تلفیقی باشد)
#      </font>
# </div>

# %%
plot(density(df$age), xlab="Age", main="density plot")
# Out:
# Plot with title “density plot”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#          و) نمودار Trend Plot
#      </font>
# </div>

# %%
ggplot(df, aes(y = income, x = age, col= gender)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال چهارم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     نمودار توزیع های احتمالی زیر را با توجه به به پارامترهای داده شده رسم کنید. <br> الف) نمودار توزیع پوآسون (در بازۀ 0 تا 50 با پارامتر 10)
#             </font>
# </div>
#     </font>
# </div>

# %%
plot(dpois(x=0:50,lambda=10), type = "h")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ب) نمودار توزیع برنولی (در بازۀ 0 تا 5 با پارامتر 0.6)
#      </font>
# </div>

# %%
library(Rlab)
library(Rlab)
x <- seq(0, 5, by = 1)
y <- dbern(x, prob = 0.6)

plot(y, type = "h")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     ج) نمودار توزیع دو جمله ای (در بازۀ 0 تا 20 با پارامتر 0.2)
#     </font>
# </div>

# %%
plot(dbinom(0:20, 20, 0.2), type = "h")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     د) نمودار توزیع هندسی (در بازۀ 0 تا 10 با پارامترهای p = 0.2 و n = 3)
#     </font>
# </div>

# %%
x <- 0:10
y <- dgeom(x=x, prob = 0.2)
plot(x, y, type="h", col = (x_data!=3) + 5, lwd = 10)
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     ه) نمودار توزیع نرمال (در بازۀ 4- تا 4)
#      </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     و) نمودار توزیع نمایی (در بازۀ 0 تا 10 با پارامتر 1.5)
#      </font>
# </div>

# %%
curve(dexp(x,rate=1.5),xlim=c(0,10))
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#      ز) نمودار توزیع یکنواخت (در بازۀ 4- تا 4)
#      </font>
# </div>

# %%
hist(runif(1000, min= -4, max= 4), xlim=c(-7,7), breaks = 5, freq=FALSE)
# Out:
# Plot with title “Histogram of runif(1000, min = -4, max = 4)”
